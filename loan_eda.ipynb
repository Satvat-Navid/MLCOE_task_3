# %% [markdown]
# ## Exploratory Data analysis on Loan Status and its Pridiction

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Imported the data frame provided as ln_df

# %%
loan_df = pd.read_csv('loan_status.csv')
loan_df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
loan_df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
loan_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
ln_df = loan_df.dropna()

# %%
sns.barplot(x='Education', y='ApplicantIncome', data=ln_df, estimator=np.median)
# Out:
# <Axes: xlabel='Education', ylabel='ApplicantIncome'>

# %% [markdown]
# ##

# %%
sns.relplot(data=ln_df, x='Loan_ID', y='ApplicantIncome')

# %%
ln_df[ln_df['ApplicantIncome'] > 30000]
# Out:
#       Loan_ID Gender Married Dependents Education Self_Employed  \
# 155  LP001536   Male     Yes         3+  Graduate            No
# 183  LP001637   Male     Yes          1  Graduate            No
# 185  LP001640   Male     Yes          0  Graduate           Yes
# 409  LP002317   Male     Yes         3+  Graduate            No
# 443  LP002422   Male      No          1  Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 155            39999                0.0       600.0             180.0
# 183            33846                0.0       260.0             360.0
# 185            39147             4750.0       120.0             360.0
# 409            81000                0.0       360.0             360.0
# 443            37719                0.0       152.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 155             0.0     Semiurban           Y
# 183             1.0     Semiurban           N
# ...

# %% [markdown]
# #### Droped the outliers for Applicant income

# %%
income_error =ln_df[ln_df['ApplicantIncome'] > 30000].index
ln_df.drop(index=income_error, inplace=True)
# Out:
# C:\Users\satwa\AppData\Local\Temp\ipykernel_6920\2248996469.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ln_df.drop(index=income_error, inplace=True)

# %% [markdown]
# #### Check the outliers for dependents

# %%
sns.relplot(data=ln_df, x='Loan_ID', y='Dependents')

# %%
ln_df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       475.000000         475.000000  475.000000        475.000000
# mean       4932.884211        1587.736674  143.117895        342.240000
# std        3369.568634        2623.407886   77.348892         65.110368
# min         150.000000           0.000000    9.000000         36.000000
# 25%        2892.000000           0.000000  100.000000        360.000000
# 50%        3850.000000        1126.000000  128.000000        360.000000
# 75%        5816.500000        2253.500000  169.000000        360.000000
# max       20233.000000       33837.000000  600.000000        480.000000
#
#        Credit_History
# count      475.000000
# mean         0.856842
# std          0.350603
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %% [markdown]
# #### Check the outliers for Coapplicant income

# %%
num_data = ["CoapplicantIncome","LoanAmount"]
for data in num_data:
    sns.relplot(data=ln_df, x='Loan_ID', y=data)

# %%
coincome_error = ln_df[ln_df['CoapplicantIncome'] > 8000].index
loan_error = ln_df[ln_df['LoanAmount'] > 350].index
ln_df.drop(index=coincome_error, inplace=True, errors='ignore')
ln_df.drop(index=loan_error, inplace=True, errors='ignore')
num_data = ["CoapplicantIncome","LoanAmount"]
for data in num_data:
    sns.relplot(data=ln_df, x='Loan_ID', y=data)
# Out:
# C:\Users\satwa\AppData\Local\Temp\ipykernel_6920\4039403297.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ln_df.drop(index=coincome_error, inplace=True, errors='ignore')
# C:\Users\satwa\AppData\Local\Temp\ipykernel_6920\4039403297.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ln_df.drop(index=loan_error, inplace=True, errors='ignore')

# %%
ln_df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
# 5  LP001011   Male     Yes          2      Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
# 5             5417             4196.0       267.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 1             1.0         Rural           N
# 2             1.0         Urban           Y
# ...

# %%
ln_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 458 entries, 1 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            458 non-null    object
#  1   Gender             458 non-null    object
#  2   Married            458 non-null    object
#  3   Dependents         458 non-null    object
#  4   Education          458 non-null    object
#  5   Self_Employed      458 non-null    object
#  6   ApplicantIncome    458 non-null    int64
#  7   CoapplicantIncome  458 non-null    float64
#  8   LoanAmount         458 non-null    float64
#  9   Loan_Amount_Term   458 non-null    float64
#  10  Credit_History     458 non-null    float64
#  11  Property_Area      458 non-null    object
#  12  Loan_Status        458 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 50.1+ KB

# %%
count_value = ['Gender', 'Married', 'Education', 'Self_Employed', 'Loan_Status']
for value in count_value:
    sns.countplot(x=value, data=ln_df)

# %%
sns.boxplot(x='Gender', y='ApplicantIncome', data=ln_df)
# Out:
# <Axes: xlabel='Gender', ylabel='ApplicantIncome'>

# %%
sns.violinplot(x='Education', y='ApplicantIncome', data=ln_df)
# Out:
# <Axes: xlabel='Education', ylabel='ApplicantIncome'>

# %%
sns.stripplot(x='Gender', y='CoapplicantIncome', data=ln_df)
# Out:
# <Axes: xlabel='Gender', ylabel='CoapplicantIncome'>

# %%
sns.swarmplot(x='Dependents', y='LoanAmount', data=ln_df)
# Out:
# c:\Users\satwa\anaconda3\envs\mlcoe\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 7.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='Dependents', ylabel='LoanAmount'>
# c:\Users\satwa\anaconda3\envs\mlcoe\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 14.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.swarmplot(x='Loan_Status', y='CoapplicantIncome', data=ln_df)
# Out:
# c:\Users\satwa\anaconda3\envs\mlcoe\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 15.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\satwa\anaconda3\envs\mlcoe\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 27.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='Loan_Status', ylabel='CoapplicantIncome'>
# c:\Users\satwa\anaconda3\envs\mlcoe\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 31.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\satwa\anaconda3\envs\mlcoe\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 34.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
# ...

# %%
sns.violinplot(x='Loan_Status', y='ApplicantIncome', data=ln_df)
# Out:
# <Axes: xlabel='Loan_Status', ylabel='ApplicantIncome'>

# %%
ln_df.nunique()
# Out:
# Loan_ID              458
# Gender                 2
# Married                2
# Dependents             4
# Education              2
# Self_Employed          2
# ApplicantIncome      387
# CoapplicantIncome    222
# LoanAmount           173
# Loan_Amount_Term       9
# Credit_History         2
# Property_Area          3
# Loan_Status            2
# dtype: int64

# %%
ln_df['Gender'].value_counts()
# Out:
# Gender
# Male      375
# Female     83
# Name: count, dtype: int64

# %%
pd.get_dummies(ln_df, columns=['Gender']).head(10)
# Out:
#      Loan_ID Married Dependents     Education Self_Employed  ApplicantIncome  \
# 1   LP001003     Yes          1      Graduate            No             4583
# 2   LP001005     Yes          0      Graduate           Yes             3000
# 3   LP001006     Yes          0  Not Graduate            No             2583
# 4   LP001008      No          0      Graduate            No             6000
# 5   LP001011     Yes          2      Graduate           Yes             5417
# 6   LP001013     Yes          0  Not Graduate            No             2333
# 7   LP001014     Yes         3+      Graduate            No             3036
# 8   LP001018     Yes          2      Graduate            No             4006
# 10  LP001024     Yes          2      Graduate            No             3200
# 13  LP001029      No          0      Graduate            No             1853
#
#     CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# ...
